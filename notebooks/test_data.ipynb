# %%
import pandas as pd

# %%
data_encoded = pd.read_csv('/Users/danyhersco/code/annabeldg/startup_project/raw_data/startups_modified.csv')

# %%
data_encoded.describe(include='all').iloc[:, 60:]
# Out:
#         Sustainability       Round 1       Round 2       Round 3  \
# count     56667.000000  4.270400e+04  1.990500e+04  1.088300e+04
# unique             NaN           NaN           NaN           NaN
# top                NaN           NaN           NaN           NaN
# freq               NaN           NaN           NaN           NaN
# mean          0.060211  7.603390e+06  9.656692e+06  1.334077e+07
# std           0.237880  1.171411e+08  8.165809e+07  5.725938e+07
# min           0.000000  1.000000e+00  1.000000e+00  2.750000e+02
# 25%           0.000000  1.396152e+05  2.650000e+05  4.169455e+05
# 50%           0.000000  5.652885e+05  1.295000e+06  2.000000e+06
# 75%           0.000000  2.430765e+06  5.000000e+06  8.399292e+06
# max           1.000000  1.660000e+10  9.049262e+09  2.262315e+09
#
#              Round 4       Round 5        Target
# count   6.201000e+03  3.560000e+03  56667.000000
# unique           NaN           NaN           NaN
# ...
