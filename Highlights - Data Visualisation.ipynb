# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ![download-7.png](attachment:download-7.png)

# %% [markdown]
# ![download-2.png](attachment:download-2.png)

# %% [markdown]
# ![download-3.png](attachment:download-3.png)

# %% [markdown]
# ![download-4.png](attachment:download-4.png)

# %% [markdown]
# ![download-5.png](attachment:download-5.png)

# %%
# !git add .

# %%
# !git commit -m "Highlights - Data Visualistion"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# To github.com:annabeldg/startup_project.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'github.com:annabeldg/startup_project.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 95 (delta 43), reused 83 (delta 31), pack-reused 0
# Unpacking objects: 100% (95/95), 50.54 KiB | 309.00 KiB/s, done.
# From github.com:annabeldg/startup_project
#    28f49cf..5d8bf82  main              -> origin/main
#  * [new branch]      notebook_addition -> origin/notebook_addition
#  * [new branch]      treat_duplicates  -> origin/treat_duplicates
#  * [new branch]      useful_lists      -> origin/useful_lists
# hint: Waiting for your editor to close the file...

# %%
# !git push origin main
